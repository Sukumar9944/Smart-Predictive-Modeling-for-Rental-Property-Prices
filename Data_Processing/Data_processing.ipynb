# %% [markdown]
# ##### **Importing necessary libraries**

# %%
import pandas as pd

# %% [markdown]
# ##### **Loading the dataset**

# %%
df = pd.read_csv(r'Dataset\House_Rent_Train .csv')
df.head()
# Out:
#                                  id  type       locality   activation_date  \
# 0  ff8081815733a243015733b2876600a6  BHK2            NaN  21-04-2018 14:44
# 1  ff8081815ee25e15015ee50004da2acd  BHK2      Bellandur   9/10/2017 12:48
# 2  ff80818163f29c9e0163f46770b873e7  BHK3  Thiruvanmiyur   12/6/2018 22:02
# 3  ff80818164b68a700164b74b1b247a1d  BHK1      Attiguppe  20-07-2018 16:22
# 4  ff80818163b1faf00163b4b9b8a163b1  BHK3      Kodihalli  31-05-2018 17:41
#
#     latitude  longitude lease_type  gym  lift  swimming_pool  ...  bathroom  \
# 0  12.934471  77.634471     FAMILY    1     1              1  ...       2.0
# 1  12.929557  77.672280     ANYONE    0     1              0  ...       2.0
# 2  12.982870  80.262012     FAMILY    0     1              0  ...       3.0
# 3  12.955991  77.531634     FAMILY    0     0              0  ...       1.0
# 4  12.963903  77.649446     FAMILY    0     0              0  ...       3.0
#
#   facing cup_board  floor  total_floor  \
# 0      E       2.0    6.0         12.0
# 1     NE       2.0    3.0          4.0
# 2      E       3.0    1.0          5.0
# 3      E       1.0    1.0          2.0
# 4      E       4.0    0.0          0.0
#
#                                            amenities water_supply  \
# 0  {"LIFT":true,"GYM":true,"INTERNET":true,"AC":f...    CORP_BORE
# 1  {"LIFT":true,"GYM":false,"INTERNET":false,"AC"...  CORPORATION
# 2  {"LIFT":true,"GYM":false,"INTERNET":false,"AC"...    CORP_BORE
# 3  {"LIFT":false,"GYM":false,"INTERNET":false,"AC...  CORPORATION
# 4  {"LIFT":false,"GYM":false,"INTERNET":false,"AC...  CORPORATION
#
#    building_type  balconies     rent
# 0             AP        2.0  40000.0
# 1             AP        2.0  22000.0
# 2             AP        3.0  28000.0
# 3             IH        0.0   8000.0
# 4             IH        1.0  45000.0
#
# [5 rows x 25 columns]

# %% [markdown]
# ##### **Basic Analysis**

# %%
df.shape
# Out:
# (20555, 25)

# %%
df.columns
# Out:
# Index(['id', 'type', 'locality', 'activation_date', 'latitude', 'longitude',
#        'lease_type', 'gym', 'lift', 'swimming_pool', 'negotiable',
#        'furnishing', 'parking', 'property_size', 'property_age', 'bathroom',
#        'facing', 'cup_board', 'floor', 'total_floor', 'amenities',
#        'water_supply', 'building_type', 'balconies', 'rent'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20555 entries, 0 to 20554
# Data columns (total 25 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               20555 non-null  object
#  1   type             20528 non-null  object
#  2   locality         20395 non-null  object
#  3   activation_date  20532 non-null  object
#  4   latitude         20532 non-null  float64
#  5   longitude        20532 non-null  float64
#  6   lease_type       20532 non-null  object
#  7   gym              20555 non-null  int64
#  8   lift             20555 non-null  int64
#  9   swimming_pool    20555 non-null  int64
#  10  negotiable       20555 non-null  int64
#  11  furnishing       20555 non-null  object
#  12  parking          20555 non-null  object
#  13  property_size    20555 non-null  int64
#  14  property_age     20532 non-null  float64
#  15  bathroom         20532 non-null  float64
#  16  facing           20532 non-null  object
#  17  cup_board        20532 non-null  float64
#  18  floor            20532 non-null  float64
#  19  total_floor      20532 non-null  float64
#  20  amenities        20532 non-null  object
#  21  water_supply     20532 non-null  object
#  22  building_type    20532 non-null  object
#  23  balconies        20532 non-null  float64
#  24  rent             20532 non-null  float64
# dtypes: float64(9), int64(5), object(11)
# memory usage: 3.9+ MB

# %%
df.describe()
# Out:
#            latitude     longitude           gym          lift  swimming_pool  \
# count  20532.000000  20532.000000  20555.000000  20555.000000   20555.000000
# mean      12.945748     77.637295      0.227049      0.362053       0.174848
# std        0.029601      0.110525      0.418935      0.480606       0.379846
# min       12.900004     77.500072      0.000000      0.000000       0.000000
# 25%       12.918176     77.572068      0.000000      0.000000       0.000000
# 50%       12.943790     77.633506      0.000000      0.000000       0.000000
# 75%       12.970979     77.695723      0.000000      1.000000       0.000000
# max       12.999999     80.266346      1.000000      1.000000       1.000000
#
#          negotiable  property_size  property_age      bathroom     cup_board  \
# count  20555.000000   20555.000000  20532.000000  20532.000000  20532.000000
# mean       0.711603    1062.017465      5.769920      1.858465      4.549922
# std        0.453028     591.207446      6.350989      0.710926    335.154787
# min        0.000000       1.000000     -1.000000      1.000000      0.000000
# 25%        0.000000     700.000000      1.000000      1.000000      1.000000
# 50%        1.000000    1047.000000      5.000000      2.000000      2.000000
# 75%        1.000000    1285.000000     10.000000      2.000000      3.000000
# max        1.000000   50000.000000    400.000000     21.000000  48026.000000
#
#               floor   total_floor     balconies          rent
# count  20532.000000  20532.000000  20532.000000  20532.000000
# mean       1.874050      3.801335      1.149523  19056.733148
# std        2.183982      3.183697      0.993549   8434.029016
# min        0.000000      0.000000      0.000000   8000.000000
# 25%        1.000000      2.000000      0.000000  12500.000000
# 50%        1.000000      3.000000      1.000000  17500.000000
# 75%        2.000000      4.000000      2.000000  24000.000000
# max       25.000000     26.000000     13.000000  50000.000000

# %%
# 1. Missing values

df.isnull().sum()

'Since there are very less number of missing values on a whole, The null values can be removed'
# Out:
# 'Since there are very less number of missing values on a whole, The null values can be removed'

# %%
# 2. Duplicated rows

df.duplicated().sum()

'Since there are duplicated rows, we can remove them'
# Out:
# 'Since there are duplicated rows, we can remove them'

# %%
print(df.value_counts())
# Out:
# id                                type      locality                    activation_date   latitude   longitude  lease_type  gym  lift  swimming_pool  negotiable  furnishing      parking       property_size  property_age  bathroom  facing  cup_board  floor  total_floor  amenities                                                                                                                                                                                                                                              water_supply  building_type  balconies  rent
# ff80818156fdef920156fe0eb0e807d0  BHK1      Malleshwaram West           8/7/2018 22:31    12.998645  77.574336  ANYONE      0    0     0              1           SEMI_FURNISHED  TWO_WHEELER   500            3.0           1.0       E       1.0        1.0    1.0          {"LIFT":false,"GYM":false,"INTERNET":false,"AC":false,"CLUB":false,"INTERCOM":false,"POOL":false,"CPA":false,"FS":false,"SERVANT":false,"SECURITY":false,"SC":true,"GP":false,"PARK":true,"RWH":false,"STP":false,"HK":false,"PB":false,"VP":false}    CORPORATION   IH             1.0        8500.0     3
# ff8081814e322687014e343219020f1b  BHK2      Bommanahalli                12/4/2018 12:53   12.904039  77.627142  FAMILY      0    0     0              1           SEMI_FURNISHED  TWO_WHEELER   700            3.0           2.0       E       2.0        1.0    3.0          {"LIFT":false,"GYM":false,"INTERNET":true,"AC":false,"CLUB":false,"INTERCOM":false,"POOL":false,"CPA":false,"FS":false,"SERVANT":false,"SECURITY":false,"SC":true,"GP":false,"PARK":true,"RWH":false,"STP":false,"HK":false,"PB":false,"VP":false}     CORPORATION   IF             1.0        13500.0    3
# ff8081815f0fe396015f13d79a4f5212  BHK1      Basavanagara                13-10-2017 10:52  12.966132  77.681297  FAMILY      0    0     0              0           SEMI_FURNISHED  BOTH          600            3.0           1.0       E       1.0        3.0    3.0          {"LIFT":false,"GYM":false,"INTERNET":false,"AC":false,"CLUB":false,"INTERCOM":false,"POOL":false,"CPA":false,"FS":false,"SERVANT":false,"SECURITY":false,"SC":true,"GP":false,"PARK":true,"RWH":false,"STP":false,"HK":false,"PB":false,"VP":false}    CORP_BORE     IH             1.0        9000.0     3
# ff80818159ded60e0159dfff948e5bcb  BHK1      Ulsoor                      11/10/2017 17:08  12.979762  77.615395  ANYONE      0    1     0              1           SEMI_FURNISHED  TWO_WHEELER   850            30.0          2.0       E       1.0        1.0    4.0          {"LIFT":true,"GYM":false,"INTERNET":true,"AC":false,"CLUB":false,"INTERCOM":false,"POOL":false,"CPA":false,"FS":true,"SERVANT":false,"SECURITY":true,"SC":true,"GP":true,"PARK":true,"RWH":false,"STP":false,"HK":true,"PB":false,"VP":true}           CORP_BORE     AP             1.0        20000.0    3
# ff8081814c6f8c9b014c6febae49016f  BHK2      Indiranagar                 28-06-2018 21:58  12.965502  77.647694  FAMILY      0    1     0              0           SEMI_FURNISHED  BOTH          1000           5.0           2.0       E       2.0        2.0    4.0          {"LIFT":true,"GYM":false,"INTERNET":true,"AC":false,"CLUB":false,"INTERCOM":false,"POOL":false,"CPA":true,"FS":true,"SERVANT":false,"SECURITY":true,"SC":true,"GP":false,"PARK":true,"RWH":false,"STP":false,"HK":true,"PB":true,"VP":true}            CORP_BORE     AP             3.0        30000.0    3
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ..
# ff8081815db1db30015db88023a843d3  BHK2      J. P. Nagar                 4/9/2017 19:56    12.910200  77.585480  FAMILY      0    0     0              0           SEMI_FURNISHED  NONE          1200           15.0          1.0       S       2.0        1.0    1.0          {"LIFT":false,"GYM":false,"INTERNET":true,"AC":false,"CLUB":false,"INTERCOM":false,"POOL":false,"CPA":false,"FS":false,"SERVANT":false,"SECURITY":false,"SC":true,"GP":false,"PARK":true,"RWH":false,"STP":false,"HK":false,"PB":false,"VP":false}     CORPORATION   IH             1.0        18000.0    1
# ff8081815db1db30015db852c4184010  BHK2      Rajarajeshwari Nagar        7/8/2017 21:39    12.927214  77.526724  ANYONE      0    0     0              1           SEMI_FURNISHED  BOTH          800            2.0           1.0       E       2.0        0.0    1.0          {"AC":false,"CLUB":false,"CPA":false,"FS":false,"GP":false,"GYM":false,"HK":false,"INTERCOM":false,"INTERNET":false,"LIFT":false,"PARK":false,"PB":false,"POOL":false,"RWH":false,"SC":false,"SECURITY":false,"SERVANT":false,"STP":false,"VP":false}  CORP_BORE     IF             0.0        9000.0     1
# ff8081815db1db30015db7852dc12503  BHK2      Munnekollal                 6/8/2017 19:09    12.948340  77.715720  FAMILY      1    1     0              1           SEMI_FURNISHED  FOUR_WHEELER  1200           2.0           2.0       E       4.0        0.0    5.0          {"LIFT":true,"GYM":true,"INTERNET":true,"AC":false,"CLUB":false,"INTERCOM":false,"POOL":false,"CPA":false,"FS":false,"SERVANT":false,"SECURITY":true,"SC":false,"GP":false,"PARK":false,"RWH":false,"STP":false,"HK":false,"PB":false,"VP":false}      CORP_BORE     AP             1.0        20000.0    1
# ff8081815db1db30015db7081a731089  BHK4PLUS  Chennammanakere Achukattu,  7/8/2017 15:57    12.940722  77.550981  FAMILY      0    0     0              1           SEMI_FURNISHED  BOTH          1570           3.0           5.0       E       10.0       0.0    3.0          {"LIFT":false,"GYM":false,"INTERNET":true,"AC":false,"CLUB":false,"INTERCOM":false,"POOL":false,"CPA":false,"FS":false,"SERVANT":false,"SECURITY":false,"SC":false,"GP":false,"PARK":false,"RWH":false,"STP":false,"HK":false,"PB":true,"VP":true}     CORP_BORE     IH             2.0        50000.0    1
# ff80818164ef74fc0164f10d9ca06fad  BHK2      Varthur                     31-07-2018 22:55  12.935728  77.747614  ANYONE      0    0     0              0           SEMI_FURNISHED  BOTH          750            3.0           1.0       N       2.0        0.0    1.0          {"LIFT":false,"GYM":false,"INTERNET":false,"AC":false,"CLUB":false,"INTERCOM":false,"POOL":false,"CPA":false,"FS":false,"SERVANT":false,"SECURITY":true,"SC":false,"GP":false,"PARK":false,"RWH":false,"STP":false,"HK":false,"PB":false,"VP":true}    BOREWELL      IH             1.0        10500.0    1
# Length: 20357, dtype: int64

# %% [markdown]
# ##### **Data Cleaning**

# %%
# 1. Removing null values

new_df = df.dropna()
new_df.isnull().sum()
# Out:
# id                 0
# type               0
# locality           0
# activation_date    0
# latitude           0
# longitude          0
# lease_type         0
# gym                0
# lift               0
# swimming_pool      0
# negotiable         0
# furnishing         0
# parking            0
# property_size      0
# property_age       0
# bathroom           0
# facing             0
# cup_board          0
# floor              0
# total_floor        0
# amenities          0
# water_supply       0
# building_type      0
# balconies          0
# rent               0
# dtype: int64

# %%
# 2. Dropping dulpicated rows

drop_df = new_df.drop_duplicates()
drop_df.duplicated().sum()
# Out:
# 0

# %%
pd.set_option('display.max_columns', 25)

# %%
drop_df.head()
# Out:
#                                  id  type              locality  \
# 1  ff8081815ee25e15015ee50004da2acd  BHK2             Bellandur
# 2  ff80818163f29c9e0163f46770b873e7  BHK3         Thiruvanmiyur
# 3  ff80818164b68a700164b74b1b247a1d  BHK1             Attiguppe
# 4  ff80818163b1faf00163b4b9b8a163b1  BHK3             Kodihalli
# 5  ff8081815f48e4aa015f4dd1a9c6696b  BHK1  Seetharampalya,Hoodi
#
#     activation_date   latitude  longitude lease_type  gym  lift  \
# 1   9/10/2017 12:48  12.929557  77.672280     ANYONE    0     1
# 2   12/6/2018 22:02  12.982870  80.262012     FAMILY    0     1
# 3  20-07-2018 16:22  12.955991  77.531634     FAMILY    0     0
# 4  31-05-2018 17:41  12.963903  77.649446     FAMILY    0     0
# 5  24-10-2017 18:29  12.986196  77.718314     FAMILY    1     1
#
#    swimming_pool  negotiable      furnishing      parking  property_size  \
# 1              0           1  SEMI_FURNISHED         BOTH           1400
# 2              0           0  SEMI_FURNISHED         BOTH           1350
# 3              0           1  SEMI_FURNISHED  TWO_WHEELER            600
# 4              0           1  SEMI_FURNISHED         BOTH           1500
# 5              1           1  SEMI_FURNISHED         BOTH           1080
#
#    property_age  bathroom facing  cup_board  floor  total_floor  \
# 1           4.0       2.0     NE        2.0    3.0          4.0
# 2           6.0       3.0      E        3.0    1.0          5.0
# 3           3.0       1.0      E        1.0    1.0          2.0
# 4          15.0       3.0      E        4.0    0.0          0.0
# 5           0.0       2.0      E        1.0    3.0          5.0
#
#                                            amenities water_supply  \
# 1  {"LIFT":true,"GYM":false,"INTERNET":false,"AC"...  CORPORATION
# 2  {"LIFT":true,"GYM":false,"INTERNET":false,"AC"...    CORP_BORE
# 3  {"LIFT":false,"GYM":false,"INTERNET":false,"AC...  CORPORATION
# 4  {"LIFT":false,"GYM":false,"INTERNET":false,"AC...  CORPORATION
# 5  {"LIFT":true,"GYM":true,"INTERNET":false,"AC":...    CORP_BORE
#
#   building_type  balconies     rent
# 1            AP        2.0  22000.0
# 2            AP        3.0  28000.0
# 3            IH        0.0   8000.0
# 4            IH        1.0  45000.0
# 5            AP        2.0  18000.0

# %%
# Dropping unneccesary columns

analysis_df = drop_df.drop(['id', 'activation_date', 'amenities', 'locality'], axis = 1)
analysis_df.head()
# Out:
#    type   latitude  longitude lease_type  gym  lift  swimming_pool  \
# 1  BHK2  12.929557  77.672280     ANYONE    0     1              0
# 2  BHK3  12.982870  80.262012     FAMILY    0     1              0
# 3  BHK1  12.955991  77.531634     FAMILY    0     0              0
# 4  BHK3  12.963903  77.649446     FAMILY    0     0              0
# 5  BHK1  12.986196  77.718314     FAMILY    1     1              1
#
#    negotiable      furnishing      parking  property_size  property_age  \
# 1           1  SEMI_FURNISHED         BOTH           1400           4.0
# 2           0  SEMI_FURNISHED         BOTH           1350           6.0
# 3           1  SEMI_FURNISHED  TWO_WHEELER            600           3.0
# 4           1  SEMI_FURNISHED         BOTH           1500          15.0
# 5           1  SEMI_FURNISHED         BOTH           1080           0.0
#
#    bathroom facing  cup_board  floor  total_floor water_supply building_type  \
# 1       2.0     NE        2.0    3.0          4.0  CORPORATION            AP
# 2       3.0      E        3.0    1.0          5.0    CORP_BORE            AP
# 3       1.0      E        1.0    1.0          2.0  CORPORATION            IH
# 4       3.0      E        4.0    0.0          0.0  CORPORATION            IH
# 5       2.0      E        1.0    3.0          5.0    CORP_BORE            AP
#
#    balconies     rent
# 1        2.0  22000.0
# 2        3.0  28000.0
# 3        0.0   8000.0
# 4        1.0  45000.0
# 5        2.0  18000.0

# %% [markdown]
# ##### **Detecting Outliers using Box Plot**

# %%
import plotly.express as px

# 1. Property Size

fig = px.box(analysis_df['property_size'])
fig.show()

# %%
# 2. Rent

fig = px.box(analysis_df['rent'])
fig.show()

# %%
# 3. property_age

fig = px.box(analysis_df['property_age'])
fig.show()

'In this box plot we can see that the max age of the property is 400, It is a error'
# Out:
# 'In this box plot we can see that the max age of the property is 400, It is a error'

# %%
ml_df = analysis_df.query('property_age !=400 and property_age >= 1')

new_df = ml_df.query('cup_board >=0 and cup_board <= 40')

fig = px.box(new_df['property_age'])
fig.show()

fig = px.box(new_df['cup_board'])
fig.show()

# %% [markdown]
# ##### **Getting the value counts of Categorical columns**

# %%
ml_df.sample()
# Out:
#        type  latitude  longitude lease_type  gym  lift  swimming_pool  \
# 11829  BHK2  12.94865  77.696136     FAMILY    1     1              1
#
#        negotiable      furnishing parking  property_size  property_age  \
# 11829           1  SEMI_FURNISHED    BOTH           1135           5.0
#
#        bathroom facing  cup_board  floor  total_floor water_supply  \
# 11829       2.0      E        2.0    2.0          3.0    CORP_BORE
#
#       building_type  balconies     rent
# 11829            AP        1.0  32000.0

# %%
new_df['type'] = new_df['type'].replace('bhk2', 'BHK2')
new_df['type'] = new_df['type'].replace('bhk3', 'BHK3')
new_df['type'] = new_df['type'].replace('1BHK1', 'BHK1')

new_df['water_supply'] = new_df['water_supply'].replace('CORP_BORE', 'CORPORATION')
# Out:
# C:\Users\Sukumar\AppData\Local\Temp\ipykernel_10248\3153688391.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Sukumar\AppData\Local\Temp\ipykernel_10248\3153688391.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Sukumar\AppData\Local\Temp\ipykernel_10248\3153688391.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Sukumar\AppData\Local\Temp\ipykernel_10248\3153688391.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
category_df = ml_df[['type','lease_type','furnishing','parking','facing','water_supply','building_type']]
category_df.head()

for i in category_df.columns:
    print(f'The value counts of {i} : {category_df[i].value_counts()}')
    print('__________________________________________________________')
# Out:
# The value counts of type : BHK2        9766
# BHK3        3576
# BHK1        2979
# RK1          448
# BHK4         199
# BHK4PLUS      24
# bhk2          11
# bhk3           7
# 1BHK1          3
# Name: type, dtype: int64
# __________________________________________________________
# The value counts of lease_type : FAMILY      8440
# ANYONE      8011
# BACHELOR     514
# COMPANY       48
# Name: lease_type, dtype: int64
# __________________________________________________________
# The value counts of furnishing : SEMI_FURNISHED     14774
# NOT_FURNISHED       1242
# FULLY_FURNISHED      997
# Name: furnishing, dtype: int64
# __________________________________________________________
# The value counts of parking : BOTH            8601
# TWO_WHEELER     6264
# FOUR_WHEELER    1212
# NONE             936
# Name: parking, dtype: int64
# __________________________________________________________
# The value counts of facing : E     7885
# N     4878
# W     2142
# S     1097
# NE     663
# SE     175
# NW     123
# SW      50
# Name: facing, dtype: int64
# __________________________________________________________
# The value counts of water_supply : CORP_BORE      8686
# CORPORATION    6067
# BOREWELL       2260
# Name: water_supply, dtype: int64
# __________________________________________________________
# The value counts of building_type : IF    8020
# AP    6858
# IH    2121
# GC      14
# Name: building_type, dtype: int64
# __________________________________________________________

# %%
#  Saving the df

new_df.to_csv('analysis_df.csv', index = False)
